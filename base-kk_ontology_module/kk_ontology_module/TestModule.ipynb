# %%
from reason import CancerOntology, test_data

# %%
o = CancerOntology()

# %%
o.define_data(test_data)

# %%
o.reason()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit:/home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpaybao6mq
# * Owlready2 * HermiT took 1.501084327697754 seconds
# * Owlready * Reparenting BreastCancerOntology.RegimenID: {owl.DatatypeProperty, BreastCancerOntology.Regimen_data} => {BreastCancerOntology.Regimen_data}
# * Owlready * Reparenting BreastCancerOntology.ICD10_Code: {owl.DatatypeProperty, BreastCancerOntology.Tumour_data} => {BreastCancerOntology.Tumour_data}
# * Owlready * Reparenting BreastCancerOntology.TumourID: {owl.DatatypeProperty, BreastCancerOntology.Tumour_data} => {BreastCancerOntology.Tumour_data}
# * Owlready * Reparenting BreastCancerOntology.DiagnosisDate: {owl.DatatypeProperty, BreastCancerOntology.Tumour_data} => {BreastCancerOntology.Tumour_data}
# * Owlready * Reparenting BreastCancerOntology.Sex: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.IsAlive: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.DateOfBirth: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.PatientID: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.VitalStatus: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.PrimaryDiagnosis: {BreastCancerOntology.Patient_data, owl.DatatypeProperty} => {BreastCancerOntology.Patient_data}
# * Owlready * Reparenting BreastCancerOntology.Dose: {BreastCancerOntology.Drug_data, owl.DatatypeProperty} => {BreastCancerOntology.Drug_data}
# * Owlready * Reparenting BreastCancerOntology.drug16: {BreastCancerOntology.Drug} => {BreastCancerOntology.CyclophosphamideDrug}
# * Owlready * Reparenting BreastCancerOntology.drug14: {BreastCancerOntology.Drug} => {BreastCancerOntology.CarboplatinDrug}
# * Owlready * Reparenting BreastCancerOntology.drug15: {BreastCancerOntology.Drug} => {BreastCancerOntology.CyclophosphamideDrug}
# * Owlready * Reparenting BreastCancerOntology.regimen9: {BreastCancerOntology.Regimen} => {BreastCancerOntology.DocetaxelContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.drug12: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * Reparenting BreastCancerOntology.regimen8: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.drug13: {BreastCancerOntology.Drug} => {BreastCancerOntology.CapecitabineDrug}
# * Owlready * Reparenting BreastCancerOntology.drug10: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * Reparenting BreastCancerOntology.drug11: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * Reparenting BreastCancerOntology.regimen17: {BreastCancerOntology.Regimen} => {BreastCancerOntology.AntiMetaboliteRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen18: {BreastCancerOntology.Regimen} => {BreastCancerOntology.PlatinumBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen11: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TaxaneContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen12: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TaxaneContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen10: {BreastCancerOntology.Regimen} => {BreastCancerOntology.DocetaxelContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen15: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen16: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen13: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen14: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.drug9: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * Reparenting BreastCancerOntology.drug8: {BreastCancerOntology.Drug} => {BreastCancerOntology.PaclitaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.drug7: {BreastCancerOntology.Drug} => {BreastCancerOntology.PaclitaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.drug2: {BreastCancerOntology.Drug} => {BreastCancerOntology.PaclitaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.drug1: {BreastCancerOntology.Drug} => {BreastCancerOntology.DocetaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.regimen4: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TaxaneContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen6: {BreastCancerOntology.Regimen} => {BreastCancerOntology.TrastuzumabBasedRegimen}
# * Owlready * Reparenting BreastCancerOntology.regimen1: {BreastCancerOntology.Regimen} => {BreastCancerOntology.DocetaxelContainingRegimen}
# * Owlready * Reparenting BreastCancerOntology.drug6: {BreastCancerOntology.Drug} => {BreastCancerOntology.DocetaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.drug5: {BreastCancerOntology.Drug} => {BreastCancerOntology.DocetaxelDrug}
# * Owlready * Reparenting BreastCancerOntology.drug4: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * Reparenting BreastCancerOntology.drug3: {BreastCancerOntology.Drug} => {BreastCancerOntology.TrastuzumabDrug}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
from datamanip import *

# %%
to_pandas(o.data, o.onto.TaxaneContainingRegimen)
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 0           20  10037882   10037882        2015-04-07          C449
# 1           21  10037882   10037882        2015-04-07          C449
# 2           22  10037882   10037882        2015-04-07          C449
# 3           85  10089744   10089744        2013-08-12          C449
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 11         322  10587361   10230501        2014-11-20           C61
#
#    SITE_ICD10_O2_3CHAR  MORPH_ICD10_O2  BEHAVIOUR_ICD10_O2 T_BEST  N_BEST  \
# 0                  C44          8090.0                   3    NaN     NaN
# 1                  C44          8090.0                   3    NaN     NaN
# 2                  C44          8090.0                   3    NaN     NaN
# 3                  C44          8090.0                   3    NaN     NaN
# 8                  C44          8090.0                   3    NaN     NaN
# 9                  C44          8090.0                   3      1     NaN
# 10                 C44          8090.0                   3    NaN     NaN
# 11                 C61          8140.0                   3     3b     0.0
#
#     ...  MERGED_REGIMEN_ID HEIGHT_AT_START_OF_REGIMEN  \
# 0   ...           10005652                       1.82
# 1   ...           10005653                       1.81
# 2   ...           10005654                       1.64
# 3   ...           10005655                        NaN
# 8   ...           10007799                       1.72
# 9   ...           10007799                       1.72
# 10  ...           10005693                       1.68
# 11  ...           10005693                       1.68
#
#     WEIGHT_AT_START_OF_REGIMEN INTENT_OF_TREATMENT  DATE_DECISION_TO_TREAT  \
# 0                        60.75                   C              2015-05-26
# 1                          NaN                   N              2014-12-09
# 2                        68.00                   D              2016-08-08
# 3                        65.30                   C              2014-10-21
# 8                          NaN                   P              2016-06-01
# 9                          NaN                   P              2016-06-01
# 10                       81.20                   P              2015-08-24
# 11                       81.20                   P              2015-08-24
#
#     START_DATE_OF_REGIMEN                 MAPPED_REGIMEN  CLINICAL_TRIAL  \
# 0              2015-07-09    Docetaxel 100mg/m2 (21 day)               N
# 1              2015-02-04                      Rituximab               2
# 2              2016-08-08                  PEMBROLIZUMAB               2
# 3              2014-10-21  Paclitaxel 80mg/m2 day 1 8 15               N
# 8              2016-06-02                      Docetaxel               N
# 9              2016-06-02                      Docetaxel               N
# 10             2015-08-26               Paclitaxel 7 day               N
# 11             2015-08-26               Paclitaxel 7 day               N
#
#     CHEMO_RADIATION  BENCHMARK_GROUP
# 0                 N        DOCETAXEL
# 1                 N        RITUXIMAB
# 2                 N    PEMBROLIZUMAB
# 3                 N       PACLITAXEL
# 8                 N        DOCETAXEL
# 9                 N        DOCETAXEL
# 10                N       PACLITAXEL
# 11                N       PACLITAXEL
#
# [8 rows x 60 columns]

# %%
has_morphology_code(o.data, codes=[8090])
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 0           20  10037882   10037882        2015-04-07          C449
# 1           21  10037882   10037882        2015-04-07          C449
# 2           22  10037882   10037882        2015-04-07          C449
# 3           85  10089744   10089744        2013-08-12          C449
# 4          115  10127559   10127559        2014-11-26          C449
# 5          116  10127559   10127559        2014-11-26          C449
# 6          117  10577081   10127559        2014-11-26          C443
# 7          118  10577081   10127559        2014-11-26          C443
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 12         329  10230548   10230548        2014-08-01          C443
# 14         351  10231893   10231893        2015-10-23          C443
#
#    SITE_ICD10_O2_3CHAR  MORPH_ICD10_O2  BEHAVIOUR_ICD10_O2 T_BEST  N_BEST  \
# 0                  C44          8090.0                   3    NaN     NaN
# 1                  C44          8090.0                   3    NaN     NaN
# 2                  C44          8090.0                   3    NaN     NaN
# 3                  C44          8090.0                   3    NaN     NaN
# 4                  C44          8090.0                   3    NaN     NaN
# 5                  C44          8090.0                   3    NaN     NaN
# 6                  C44          8090.0                   3    NaN     NaN
# 7                  C44          8090.0                   3    NaN     NaN
# 8                  C44          8090.0                   3    NaN     NaN
# 9                  C44          8090.0                   3      1     NaN
# 10                 C44          8090.0                   3    NaN     NaN
# 12                 C44          8090.0                   3    NaN     NaN
# 14                 C44          8090.0                   3    NaN     NaN
#
#     ...  MERGED_REGIMEN_ID HEIGHT_AT_START_OF_REGIMEN  \
# 0   ...           10005652                       1.82
# 1   ...           10005653                       1.81
# 2   ...           10005654                       1.64
# 3   ...           10005655                        NaN
# 4   ...           10005688                       1.70
# 5   ...           10007798                       1.78
# 6   ...           10005688                       1.70
# 7   ...           10007798                       1.78
# 8   ...           10007799                       1.72
# 9   ...           10007799                       1.72
# 10  ...           10005693                       1.68
# 12  ...           10007801                       1.64
# 14  ...           10005698                        NaN
#
#     WEIGHT_AT_START_OF_REGIMEN INTENT_OF_TREATMENT  DATE_DECISION_TO_TREAT  \
# 0                       60.750                   C              2015-05-26
# 1                          NaN                   N              2014-12-09
# 2                       68.000                   D              2016-08-08
# 3                       65.300                   C              2014-10-21
# 4                       82.699                   C              2016-03-19
# 5                       94.250                   P              2015-07-27
# 6                       82.699                   C              2016-03-19
# 7                       94.250                   P              2015-07-27
# 8                          NaN                   P              2016-06-01
# 9                          NaN                   P              2016-06-01
# 10                      81.200                   P              2015-08-24
# 12                      72.000                   D              2015-12-04
# 14                         NaN                   P              2017-03-25
#
#     START_DATE_OF_REGIMEN                     MAPPED_REGIMEN  CLINICAL_TRIAL  \
# 0              2015-07-09        Docetaxel 100mg/m2 (21 day)               N
# 1              2015-02-04                          Rituximab               2
# 2              2016-08-08                      PEMBROLIZUMAB               2
# 3              2014-10-21      Paclitaxel 80mg/m2 day 1 8 15               N
# 4              2016-04-02  Oxaliplatin + Modified de Gramont               N
# 5              2015-08-16           Trastuzumab Subcutaneous               Y
# 6              2016-04-02  Oxaliplatin + Modified de Gramont               N
# 7              2015-08-16           Trastuzumab Subcutaneous               Y
# 8              2016-06-02                          Docetaxel               N
# 9              2016-06-02                          Docetaxel               N
# 10             2015-08-26                   Paclitaxel 7 day               N
# 12             2015-12-06     Trastuzumab 21 day maintenance               N
# 14             2017-03-27           Trastuzumab Subcutaneous               N
#
#     CHEMO_RADIATION    BENCHMARK_GROUP
# 0                 N          DOCETAXEL
# 1                 N          RITUXIMAB
# 2                 N      PEMBROLIZUMAB
# 3                 N         PACLITAXEL
# 4                 N  OXALIPLATIN + MDG
# 5                 N        TRASTUZUMAB
# 6                 N  OXALIPLATIN + MDG
# 7                 N        TRASTUZUMAB
# 8                 N          DOCETAXEL
# 9                 N          DOCETAXEL
# 10                N         PACLITAXEL
# 12                N        TRASTUZUMAB
# 14                N        TRASTUZUMAB
#
# [13 rows x 60 columns]

# %%
has_icd10_code(o.data, codes=['C504'])
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 11         322  10587361   10230501        2014-11-20           C61
#
#    SITE_ICD10_O2_3CHAR  MORPH_ICD10_O2  BEHAVIOUR_ICD10_O2 T_BEST  N_BEST  \
# 8                  C44          8090.0                   3    NaN     NaN
# 9                  C44          8090.0                   3      1     NaN
# 10                 C44          8090.0                   3    NaN     NaN
# 11                 C61          8140.0                   3     3b     0.0
#
#     ...  MERGED_REGIMEN_ID HEIGHT_AT_START_OF_REGIMEN  \
# 8   ...           10007799                       1.72
# 9   ...           10007799                       1.72
# 10  ...           10005693                       1.68
# 11  ...           10005693                       1.68
#
#     WEIGHT_AT_START_OF_REGIMEN INTENT_OF_TREATMENT  DATE_DECISION_TO_TREAT  \
# 8                          NaN                   P              2016-06-01
# 9                          NaN                   P              2016-06-01
# 10                        81.2                   P              2015-08-24
# 11                        81.2                   P              2015-08-24
#
#     START_DATE_OF_REGIMEN    MAPPED_REGIMEN  CLINICAL_TRIAL  CHEMO_RADIATION  \
# 8              2016-06-02         Docetaxel               N                N
# 9              2016-06-02         Docetaxel               N                N
# 10             2015-08-26  Paclitaxel 7 day               N                N
# 11             2015-08-26  Paclitaxel 7 day               N                N
#
#     BENCHMARK_GROUP
# 8         DOCETAXEL
# 9         DOCETAXEL
# 10       PACLITAXEL
# 11       PACLITAXEL
#
# [4 rows x 60 columns]

# %%
'''
8500
8510 ductal
8521 lobular 
'''
