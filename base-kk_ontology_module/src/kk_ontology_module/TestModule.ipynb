# %%
from reason import CancerOntology, test_data
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit:/home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmp6i49ffb7
# * Owlready2 * HermiT took 1.041869878768921 seconds
# * Owlready * Reparenting CancerOntology.RegimenID: {CancerOntology.Regimen_data, owl.DatatypeProperty} => {CancerOntology.Regimen_data}
# * Owlready * Reparenting CancerOntology.Dose: {CancerOntology.Drug_data, owl.DatatypeProperty} => {CancerOntology.Drug_data}
# * Owlready * Reparenting CancerOntology.DiagnosisDate: {CancerOntology.Tumour_data, owl.DatatypeProperty} => {CancerOntology.Tumour_data}
# * Owlready * Reparenting CancerOntology.ICD10_Code: {CancerOntology.Tumour_data, owl.DatatypeProperty} => {CancerOntology.Tumour_data}
# ...

# %%
o = CancerOntology()

# %%
o.define_data(test_data)

# %%
o.reason()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit:/home/kaixuankhoo98/.local/lib/python3.10/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpt5771l11
# * Owlready2 * HermiT took 1.3767409324645996 seconds
# * Owlready * Equivalenting: CancerOntology.Tumour_Breast CancerOntology.Tumour_C50_C50
# * Owlready * Equivalenting: CancerOntology.Tumour_C50_C50 CancerOntology.Tumour_Breast
# * Owlready * Equivalenting: CancerOntology.Tumour_Brain CancerOntology.Tumour_C71
# * Owlready * Equivalenting: CancerOntology.Tumour_C71 CancerOntology.Tumour_Brain
# * Owlready * Reparenting CancerOntology.FEC: {CancerOntology.AntiMetaboliteRegimen, CancerOntology.Regimen} => {CancerOntology.AntiMetaboliteRegimen}
# * Owlready * Reparenting CancerOntology.drug19: {CancerOntology.Drug} => {CancerOntology.TrastuzumabDrug}
# ...

# %%
from datamanip import *

# %%
to_pandas(o.data, o.onto.TaxaneContainingRegimen)
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 0           20  10037882   10037882        2015-04-07          C449
# 1           21  10037882   10037882        2015-04-07          C449
# 2           22  10037882   10037882        2015-04-07          C449
# 3           85  10089744   10089744        2013-08-12          C449
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 11         322  10587361   10230501        2014-11-20           C61
#
#    SITE_ICD10_O2_3CHAR  MORPH_ICD10_O2  BEHAVIOUR_ICD10_O2 T_BEST  N_BEST  \
# 0                  C44          8090.0                   3    NaN     NaN
# 1                  C44          8090.0                   3    NaN     NaN
# 2                  C44          8090.0                   3    NaN     NaN
# ...

# %%
has_morphology_code(o.data, codes=[8090])
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 0           20  10037882   10037882        2015-04-07          C449
# 1           21  10037882   10037882        2015-04-07          C449
# 2           22  10037882   10037882        2015-04-07          C449
# 3           85  10089744   10089744        2013-08-12          C449
# 4          115  10127559   10127559        2014-11-26          C449
# 5          116  10127559   10127559        2014-11-26          C449
# 6          117  10577081   10127559        2014-11-26          C443
# 7          118  10577081   10127559        2014-11-26          C443
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 12         329  10230548   10230548        2014-08-01          C443
# 14         351  10231893   10231893        2015-10-23          C443
#
# ...

# %%
has_icd10_code(o.data, codes=['C504'])
# Out:
#     Unnamed: 0  TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 8          157  10162550   10162550        2015-04-10          C449
# 9          158  10580475   10162550        2015-04-10          C447
# 10         321  10230501   10230501        2014-09-08          C443
# 11         322  10587361   10230501        2014-11-20           C61
#
#    SITE_ICD10_O2_3CHAR  MORPH_ICD10_O2  BEHAVIOUR_ICD10_O2 T_BEST  N_BEST  \
# 8                  C44          8090.0                   3    NaN     NaN
# 9                  C44          8090.0                   3      1     NaN
# 10                 C44          8090.0                   3    NaN     NaN
# 11                 C61          8140.0                   3     3b     0.0
#
#     ...  MERGED_REGIMEN_ID HEIGHT_AT_START_OF_REGIMEN  \
# 8   ...           10007799                       1.72
# 9   ...           10007799                       1.72
# 10  ...           10005693                       1.68
# ...

# %%
'''
8500
8510 ductal
8521 lobular 
'''
